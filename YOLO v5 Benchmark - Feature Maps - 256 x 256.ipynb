# %% [markdown]
# ### Notes:
#
# This version of the notebook is used for running the most recent version YOLO v5 which has feature maps to show which featuers are the most important. It can be used for re-training the model as needed.

# %%
import os
os.chdir("D:\\Datasets\\SIIM_RSNA_Covid_Datasets")
os.getcwd()
# Out:
# 'D:\\Datasets\\SIIM_RSNA_Covid_Datasets'

# %%
# Set up OS and run to get YOLO v5 in the tmp folder

# !mkdir tmp
# %cd tmp
# %cd ../

# !git clone https://github.com/ultralytics/yolov5
# %cd yolov5
# !pip install -r requirements.txt
# Out:
# D:\Datasets\SIIM_RSNA_Covid_Datasets\tmp

# %%
import torch
print(f"Setup complete. Using torch {torch.__version__} ({torch.cuda.get_device_properties(0).name if torch.cuda.is_available() else 'CPU'})")

# Install W&B 
# !pip install -q --upgrade wandb
# Login 

import wandb
wandb.login()

# Necessary/extra dependencies. 
import os
import gc
import cv2
import numpy as np
import pandas as pd
from tqdm import tqdm
from shutil import copyfile
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

#customize iPython writefile so we can write variables
from IPython.core.magic import register_line_cell_magic

@register_line_cell_magic
def writetemplate(line, cell):
    with open(line, 'w') as f:
        f.write(cell.format(**globals()))
# Out:
# Setup complete. Using torch 1.8.1 (NVIDIA GeForce GTX 1080 Ti)
# wandb: Currently logged in as: ogk01 (use `wandb login --relogin` to force relogin)

# %% [markdown]
# # 🦆 Hyperparameters

# %%
TRAIN_PATH = 'D:\\Datasets\\SIIM_RSNA_Covid_Datasets\\train_jpeg\\'
train_image_level_filepath = 'D:\\Datasets\\SIIM_RSNA_Covid_Datasets\\train_image_level.csv'
meta_filepath = 'D:\\Datasets\\SIIM_RSNA_Covid_Datasets\\meta_256.csv'
yolo_yaml_filepath = 'D:\\Datasets\\SIIM_RSNA_Covid_Datasets\\tmp\\yolov5\\data\\data.yaml'
IMG_SIZE = 256
BATCH_SIZE = 256
EPOCHS = 20

# %% [markdown]
# # 🔨 Prepare Dataset
#
# This is the most important section when it comes to training an object detector with YOLOv5. The directory structure, bounding box format, etc must be in the correct order. This section builds every piece needed to train a YOLOv5 model.
#
# I am using [xhlulu's](https://www.kaggle.com/xhlulu) resized dataset. The uploaded 256x256 Kaggle dataset is [here](https://www.kaggle.com/xhlulu/siim-covid19-resized-to-256px-jpg). Find other image resolutions [here](https://www.kaggle.com/c/siim-covid19-detection/discussion/239918).
#
# * Create train-validation split. <br>
# * Create required `/dataset` folder structure and more the images to that folder. <br>
# * Create `data.yaml` file needed to train the model. <br>
# * Create bounding box coordinates in the required YOLO format.

# %%
# Everything is done from /kaggle directory.
#%cd ../

# Load image level csv file
df = pd.read_csv(train_image_level_filepath)

# Modify values in the id column
df['id'] = df.apply(lambda row: row.id.split('_')[0], axis=1)

# Add absolute path
df['path'] = df.apply(lambda row: TRAIN_PATH+row.id+'.jpg', axis=1)

# Get image level labels
df['image_level'] = df.apply(lambda row: row.label.split(' ')[0], axis=1)

df.head(5)

# Load meta.csv file
# Original dimensions are required to scale the bounding box coordinates appropriately.
meta_df = pd.read_csv(meta_filepath)
train_meta_df = meta_df.loc[meta_df.split == 'train']
train_meta_df = train_meta_df.drop('split', axis=1)
train_meta_df.columns = ['id', 'dim0', 'dim1']
train_meta_df.head(2)

# Merge both the dataframes
df = df.merge(train_meta_df, on='id',how="left")
df.head(2)
# Out:
#              id                                              boxes  \
# 0  000a312787f2  [{'x': 789.28836, 'y': 582.43035, 'width': 102...
# 1  000c3a3f293f                                                NaN
#
#                                                label StudyInstanceUID  \
# 0  opacity 1 789.28836 582.43035 1815.94498 2499....     5776db0cec75
# 1                                     none 1 0 0 1 1     ff0879eb20ed
#
#                                                 path image_level  dim0  dim1
# 0  D:\Datasets\SIIM_RSNA_Covid_Datasets\train_jpe...     opacity  3488  4256
# 1  D:\Datasets\SIIM_RSNA_Covid_Datasets\train_jpe...        none  2320  2832

# %% [markdown]
# ## 🍘 Train-validation split

# %%
# Create train and validation split.
train_df, valid_df = train_test_split(df, test_size=0.2, random_state=42, stratify=df.image_level.values)

train_df.loc[:, 'split'] = 'train'
valid_df.loc[:, 'split'] = 'valid'

df = pd.concat([train_df, valid_df]).reset_index(drop=True)

print(f'Size of dataset: {len(df)}, training images: {len(train_df)}. validation images: {len(valid_df)}')
# Out:
# Size of dataset: 6334, training images: 5067. validation images: 1267
# D:\Anaconda\envs\Pytorch\lib\site-packages\pandas\core\indexing.py:1597: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = value
# D:\Anaconda\envs\Pytorch\lib\site-packages\pandas\core\indexing.py:1720: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)

# %% [markdown]
# ## 🍚 Prepare Required Folder Structure
#
# The required folder structure for the dataset directory is:
#
# ```
# /parent_folder
#     /dataset
#          /images
#              /train
#              /val
#          /labels
#              /train
#              /val
#     /yolov5
# ```
#
# Note that I have named the directory `covid`.

# %%
os.chdir("D:\\Datasets\\SIIM_RSNA_Covid_Datasets\\")
os.makedirs('tmp/covid/images/train', exist_ok=True)
os.makedirs('tmp/covid/images/valid', exist_ok=True)

os.makedirs('tmp/covid/labels/train', exist_ok=True)
os.makedirs('tmp/covid/labels/valid', exist_ok=True)

#!ls tmp/covid/images

# Move the images to relevant split folder.
for i in tqdm(range(len(df))):
    row = df.loc[i]
    if row.split == 'train':
        copyfile(row.path, f'D:\\Datasets\\SIIM_RSNA_Covid_Datasets\\tmp\\covid\\images\\train\\{row.id}.jpg')
    else:
        copyfile(row.path, f'D:\\Datasets\\SIIM_RSNA_Covid_Datasets\\tmp\\covid\\images\\valid\\{row.id}.jpg')
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████| 6334/6334 [00:51<00:00, 122.71it/s]

# %% [markdown]
# #### Copy the images into the tmp folder created above

# %% [markdown]
# ## 🍜 Create `.YAML` file
#
# The `data.yaml`, is the dataset configuration file that defines
#
# 1. an "optional" download command/URL for auto-downloading,
# 2. a path to a directory of training images (or path to a *.txt file with a list of training images),
# 3. a path to a directory of validation images (or path to a *.txt file with a list of validation images),
# 4. the number of classes,
# 5. a list of class names.
#
# > 📍 Important: In this competition, each image can either belong to `opacity` or `none` image-level labels. That's why I have  used the number of classes, `nc` to be 2. YOLOv5 automatically handles the images without any bounding box coordinates.
#
# > 📍 Note: The `data.yaml` is created in the `yolov5/data` directory as required.

# %%
# Create .yaml file 
import yaml

data_yaml = dict(
    train = '../covid/images/train',
    val = '../covid/images/valid',
    nc = 2,
    names = ['none', 'opacity']
)

# Note that I am creating the file in the yolov5/data/ directory.
with open(yolo_yaml_filepath, 'w') as outfile:
    yaml.dump(data_yaml, outfile, default_flow_style=True)
    
#%cat tmp/yolov5/data/data.yaml

# %% [markdown]
# ## 🍮 Prepare Bounding Box Coordinated for YOLOv5
#
# For every image with **bounding box(es)** a `.txt` file with the same name as the image will be created in the format shown below:
#
# * One row per object. <br>
# * Each row is class `x_center y_center width height format`. <br>
# * Box coordinates must be in normalized xywh format (from 0 - 1). We can normalize by the boxes in pixels by dividing `x_center` and `width` by image width, and `y_center` and `height` by image height. <br>
# * Class numbers are zero-indexed (start from 0). <br>
#
# > 📍 Note: We don't have to remove the images without bounding boxes from the training or validation sets.

# %%
# Get the raw bounding box by parsing the row value of the label column.
# Ref: https://www.kaggle.com/yujiariyasu/plot-3positive-classes
def get_bbox(row):
    bboxes = []
    bbox = []
    for i, l in enumerate(row.label.split(' ')):
        if (i % 6 == 0) | (i % 6 == 1):
            continue
        bbox.append(float(l))
        if i % 6 == 5:
            bboxes.append(bbox)
            bbox = []  
            
    return bboxes

# Scale the bounding boxes according to the size of the resized image. 
def scale_bbox(row, bboxes):
    # Get scaling factor
    scale_x = IMG_SIZE/row.dim1
    scale_y = IMG_SIZE/row.dim0
    
    scaled_bboxes = []
    for bbox in bboxes:
        x = int(np.round(bbox[0]*scale_x, 4))
        y = int(np.round(bbox[1]*scale_y, 4))
        x1 = int(np.round(bbox[2]*(scale_x), 4))
        y1= int(np.round(bbox[3]*scale_y, 4))

        scaled_bboxes.append([x, y, x1, y1]) # xmin, ymin, xmax, ymax
        
    return scaled_bboxes

# Convert the bounding boxes in YOLO format.
def get_yolo_format_bbox(img_w, img_h, bboxes):
    yolo_boxes = []
    for bbox in bboxes:
        w = bbox[2] - bbox[0] # xmax - xmin
        h = bbox[3] - bbox[1] # ymax - ymin
        xc = bbox[0] + int(np.round(w/2)) # xmin + width/2
        yc = bbox[1] + int(np.round(h/2)) # ymin + height/2
        
        yolo_boxes.append([xc/img_w, yc/img_h, w/img_w, h/img_h]) # x_center y_center width height
    
    return yolo_boxes

# Prepare the txt files for bounding box
for i in tqdm(range(len(df))):
    row = df.loc[i]
    # Get image id
    img_id = row.id
    # Get split
    split = row.split
    # Get image-level label
    label = row.image_level
    
    if row.split=='train':
        file_name = f'tmp/covid/labels/train/{row.id}.txt'
    else:
        file_name = f'tmp/covid/labels/valid/{row.id}.txt'
        
    
    if label=='opacity':
        # Get bboxes
        bboxes = get_bbox(row)
        # Scale bounding boxes
        scale_bboxes = scale_bbox(row, bboxes)
        # Format for YOLOv5
        yolo_bboxes = get_yolo_format_bbox(IMG_SIZE, IMG_SIZE, scale_bboxes)
        
        with open(file_name, 'w') as f:
            for bbox in yolo_bboxes:
                bbox = [1]+bbox
                bbox = [str(i) for i in bbox]
                bbox = ' '.join(bbox)
                f.write(bbox)
                f.write('\n')
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████| 6334/6334 [00:15<00:00, 396.15it/s]

# %% [markdown]
# # 🚅 Train with W&B

# %% [markdown]
# #%cd tmp/yolov5/
# ```
# --img {IMG_SIZE} \ # Input image size.
# --batch {BATCH_SIZE} \ # Batch size
# --epochs {EPOCHS} \ # Number of epochs
# --data data.yaml \ # Configuration file
# --weights yolov5s.pt \ # Model name
# --save_period 1\ # Save model after interval
# --project kaggle-siim-covid # W&B project name
# ```

# %%
os.chdir("D:\\Datasets\\SIIM_RSNA_Covid_Datasets\\tmp\\yolov5")
os.getcwd()
# Out:
# 'D:\\Datasets\\SIIM_RSNA_Covid_Datasets\\tmp\\yolov5'

# %%
# !python train.py --img {IMG_SIZE} \
                 --batch {BATCH_SIZE} \
                 --epochs {EPOCHS} \
                 --data data.yaml \
                 --weights yolov5s.pt \
                 --save_period 1\
                 --project kaggle-siim-covid
# Out:
# train: weights=yolov5s.pt, cfg=, data=data.yaml, hyp=data/hyps/hyp.scratch.yaml, epochs=20, batch_size=256, img_size=[256], rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, evolve=None, bucket=, cache_images=False, image_weights=False, device=, multi_scale=False, single_cls=False, adam=False, sync_bn=False, workers=8, project=kaggle-siim-covid, entity=None, name=exp, exist_ok=False, quad=False, linear_lr=False, label_smoothing=0.0, upload_dataset=False, bbox_interval=-1, save_period=1, artifact_alias=latest, local_rank=-1
# github: up to date with https://github.com/ultralytics/yolov5
#
# Downloading https://github.com/ultralytics/yolov5/releases/download/v5.0/yolov5s.pt to yolov5s.pt...
#
# Plotting labels...
#
# autoanchor: Analyzing anchors... anchors/target = 5.77, Best Possible Recall (BPR) = 1.0000
#                  all       1267       1582     0.0141     0.0714    0.00744    0.00121
# Saving model artifact on epoch  1
#                  all       1267       1582      0.052      0.135     0.0236    0.00432
# Saving model artifact on epoch  2
#                  all       1267       1582      0.106      0.237     0.0695     0.0112
# Saving model artifact on epoch  3
#                  all       1267       1582      0.108      0.286     0.0764     0.0137
# Saving model artifact on epoch  4
#                  all       1267       1582      0.375        0.3      0.228     0.0497
# Saving model artifact on epoch  5
#                  all       1267       1582      0.411      0.352      0.274     0.0669
# Saving model artifact on epoch  6
#                  all       1267       1582      0.434      0.343      0.273     0.0647
# Saving model artifact on epoch  7
#                  all       1267       1582      0.414      0.374      0.276     0.0711
# Saving model artifact on epoch  8
#                  all       1267       1582      0.437      0.399      0.301     0.0838
# Saving model artifact on epoch  9
#                  all       1267       1582      0.451      0.397      0.318      0.089
# Saving model artifact on epoch  10
#                  all       1267       1582      0.507      0.369      0.339     0.0994
# Saving model artifact on epoch  11
#                  all       1267       1582      0.435      0.399      0.331      0.096
# Saving model artifact on epoch  12
#                  all       1267       1582       0.46      0.451      0.361      0.107
# Saving model artifact on epoch  13
#                  all       1267       1582      0.474       0.44      0.353      0.109
# Saving model artifact on epoch  14
#                  all       1267       1582      0.535      0.411      0.405      0.114
# Saving model artifact on epoch  15
#                  all       1267       1582      0.501      0.419      0.383      0.114
# Saving model artifact on epoch  16
#                  all       1267       1582      0.517      0.445      0.414      0.117
# Saving model artifact on epoch  17
#                  all       1267       1582      0.445      0.466      0.374       0.11
# Saving model artifact on epoch  18
#                  all       1267       1582      0.532      0.446       0.42      0.124
# Saving model artifact on epoch  19
#                  all       1267       1582      0.569      0.427       0.43      0.127
#              opacity       1267       1582      0.569      0.427       0.43      0.127
# Optimizer stripped from kaggle-siim-covid\exp\weights\last.pt, 14.3MB
# Optimizer stripped from kaggle-siim-covid\exp\weights\best.pt, 14.3MB
# YOLOv5  v5.0-295-g9dd33fd torch 1.8.1 CUDA:0 (NVIDIA GeForce GTX 1080 Ti, 11264.0MB)
#
# hyperparameters: lr0=0.01, lrf=0.2, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=0.05, cls=0.5, cls_pw=1.0, obj=1.0, obj_pw=1.0, iou_t=0.2, anchor_t=4.0, fl_gamma=0.0, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0
# tensorboard: Start with 'tensorboard --logdir kaggle-siim-covid', view at http://localhost:6006/
# wandb: Currently logged in as: ogk01 (use `wandb login --relogin` to force relogin)
# wandb: wandb version 0.11.0 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
# wandb: Tracking run with wandb version 0.10.30
# wandb: Syncing run exp
# wandb:  View project at https://wandb.ai/ogk01/kaggle-siim-covid
# wandb:  View run at https://wandb.ai/ogk01/kaggle-siim-covid/runs/3co6ia1q
# wandb: Run data is saved locally in D:\Datasets\SIIM_RSNA_Covid_Datasets\tmp\yolov5\wandb\run-20210718_172904-3co6ia1q
# wandb: Run `wandb offline` to turn off syncing.
#
#   0%|          | 0.00/14.1M [00:00<?, ?B/s]
#  26%|##5       | 3.66M/14.1M [00:00<00:00, 31.0MB/s]
#  83%|########2 | 11.7M/14.1M [00:00<00:00, 38.2MB/s]
# 100%|##########| 14.1M/14.1M [00:00<00:00, 62.1MB/s]
# Overriding model.yaml nc=80 with nc=2
#
#                  from  n    params  module                                  arguments
#   0                -1  1      3520  models.common.Focus                     [3, 32, 3]
#   1                -1  1     18560  models.common.Conv                      [32, 64, 3, 2]
#   2                -1  1     18816  models.common.C3                        [64, 64, 1]
#   3                -1  1     73984  models.common.Conv                      [64, 128, 3, 2]
#   4                -1  1    156928  models.common.C3                        [128, 128, 3]
#   5                -1  1    295424  models.common.Conv                      [128, 256, 3, 2]
#   6                -1  1    625152  models.common.C3                        [256, 256, 3]
#   7                -1  1   1180672  models.common.Conv                      [256, 512, 3, 2]
#   8                -1  1    656896  models.common.SPP                       [512, 512, [5, 9, 13]]
#   9                -1  1   1182720  models.common.C3                        [512, 512, 1, False]
#  10                -1  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  11                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  12           [-1, 6]  1         0  models.common.Concat                    [1]
#  13                -1  1    361984  models.common.C3                        [512, 256, 1, False]
#  14                -1  1     33024  models.common.Conv                      [256, 128, 1, 1]
#  15                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  16           [-1, 4]  1         0  models.common.Concat                    [1]
#  17                -1  1     90880  models.common.C3                        [256, 128, 1, False]
#  18                -1  1    147712  models.common.Conv                      [128, 128, 3, 2]
#  19          [-1, 14]  1         0  models.common.Concat                    [1]
#  20                -1  1    296448  models.common.C3                        [256, 256, 1, False]
#  21                -1  1    590336  models.common.Conv                      [256, 256, 3, 2]
#  22          [-1, 10]  1         0  models.common.Concat                    [1]
#  23                -1  1   1182720  models.common.C3                        [512, 512, 1, False]
#  24      [17, 20, 23]  1     18879  models.yolo.Detect                      [2, [[10, 13, 16, 30, 33, 23], [30, 61, 62, 45, 59, 119], [116, 90, 156, 198, 373, 326]], [128, 256, 512]]
# Model Summary: 283 layers, 7066239 parameters, 7066239 gradients, 16.4 GFLOPs
#
# Transferred 356/362 items from yolov5s.pt
# Scaled weight_decay = 0.002
# Optimizer groups: 62 .bias, 62 conv.weight, 59 other
# albumentations: version 1.0.2 required by YOLOv5, but version 1.0.0 is currently installed
#
# train: Scanning '..\covid\labels\train' images and labels...:   0%|          | 0/5067 [00:00<?, ?it/s]
# train: Scanning '..\covid\labels\train' images and labels...0 found, 1 missing, 0 empty, 0 corrupted:   0%|          | 1/5067 [00:04<5:40:05,  4.03s/it]
# train: Scanning '..\covid\labels\train' images and labels...221 found, 117 missing, 0 empty, 0 corrupted:   7%|6         | 338/5067 [00:04<3:42:14,  2.82s/it]
# train: Scanning '..\covid\labels\train' images and labels...529 found, 255 missing, 0 empty, 0 corrupted:  15%|#5        | 784/5067 [00:04<2:20:54,  1.97s/it]
# train: Scanning '..\covid\labels\train' images and labels...833 found, 414 missing, 0 empty, 0 corrupted:  25%|##4       | 1247/5067 [00:04<1:27:58,  1.38s/it]
# train: Scanning '..\covid\labels\train' images and labels...1147 found, 561 missing, 0 empty, 0 corrupted:  34%|###3      | 1708/5067 [00:04<54:09,  1.03it/s]
# train: Scanning '..\covid\labels\train' images and labels...1473 found, 719 missing, 0 empty, 0 corrupted:  43%|####3     | 2192/5067 [00:04<32:26,  1.48it/s]
# train: Scanning '..\covid\labels\train' images and labels...1804 found, 887 missing, 0 empty, 0 corrupted:  53%|#####3    | 2691/5067 [00:04<18:46,  2.11it/s]
# train: Scanning '..\covid\labels\train' images and labels...2160 found, 1045 missing, 0 empty, 0 corrupted:  63%|######3   | 3205/5067 [00:04<10:18,  3.01it/s]
# train: Scanning '..\covid\labels\train' images and labels...2498 found, 1202 missing, 0 empty, 0 corrupted:  73%|#######3  | 3700/5067 [00:04<05:17,  4.30it/s]
# train: Scanning '..\covid\labels\train' images and labels...2809 found, 1350 missing, 0 empty, 0 corrupted:  82%|########2 | 4159/5067 [00:04<02:27,  6.14it/s]
# train: Scanning '..\covid\labels\train' images and labels...3130 found, 1498 missing, 0 empty, 0 corrupted:  91%|#########1| 4628/5067 [00:05<00:50,  8.77it/s]
# train: Scanning '..\covid\labels\train' images and labels...3435 found, 1632 missing, 0 empty, 0 corrupted: 100%|##########| 5067/5067 [00:05<00:00, 990.04it/s]
# train: New cache created: ..\covid\labels\train.cache
#
# val: Scanning '..\covid\labels\valid' images and labels...:   0%|          | 0/1267 [00:00<?, ?it/s]
# val: Scanning '..\covid\labels\valid' images and labels...0 found, 1 missing, 0 empty, 0 corrupted:   0%|          | 1/1267 [00:05<1:54:21,  5.42s/it]
# val: Scanning '..\covid\labels\valid' images and labels...182 found, 87 missing, 0 empty, 0 corrupted:  21%|##1       | 269/1267 [00:05<1:03:06,  3.79s/it]
# val: Scanning '..\covid\labels\valid' images and labels...470 found, 220 missing, 0 empty, 0 corrupted:  54%|#####4    | 690/1267 [00:05<25:32,  2.66s/it]
# val: Scanning '..\covid\labels\valid' images and labels...818 found, 394 missing, 0 empty, 0 corrupted:  96%|#########5| 1212/1267 [00:05<01:42,  1.86s/it]
# val: Scanning '..\covid\labels\valid' images and labels...859 found, 408 missing, 0 empty, 0 corrupted: 100%|##########| 1267/1267 [00:05<00:00, 221.08it/s]
# val: New cache created: ..\covid\labels\valid.cache
# Image sizes 256 train, 256 val
# Using 8 dataloader workers
# Logging results to kaggle-siim-covid\exp
# Starting training for 20 epochs...
#
#      Epoch   gpu_mem       box       obj       cls     total    labels  img_size
#
#   0%|          | 0/20 [00:00<?, ?it/s]
#

#
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95:   0%|          | 0/3 [00:00<?, ?it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95:  33%|###3      | 1/3 [00:03<00:07,  3.76s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95:  67%|######6   | 2/3 [00:07<00:03,  3.61s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100%|##########| 3/3 [00:08<00:00,  3.01s/it]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100%|##########| 3/3 [00:08<00:00,  2.87s/it]
# 20 epochs completed in 0.091 hours.
#
# wandb: Waiting for W&B process to finish, PID 25412
# wandb: Program ended successfully.
# wandb: - 1049.06MB of 1049.60MB uploaded (0.00MB deduped)
# wandb: \ 1049.60MB of 1049.60MB uploaded (0.00MB deduped)
# wandb: | 1055.35MB of 1064.18MB uploaded (0.00MB deduped)
# wandb: / 1056.48MB of 1064.24MB uploaded (0.00MB deduped)
# wandb: - 1057.07MB of 1064.24MB uploaded (0.00MB deduped)
# wandb: \ 1057.64MB of 1064.24MB uploaded (0.00MB deduped)
# wandb: | 1058.47MB of 1064.24MB uploaded (0.00MB deduped)
# wandb: / 1058.87MB of 1064.24MB uploaded (0.00MB deduped)
# wandb: - 1059.31MB of 1064.24MB uploaded (0.00MB deduped)
# wandb: \ 1059.46MB of 1064.24MB uploaded (0.00MB deduped)
# wandb: | 1059.77MB of 1064.24MB uploaded (0.00MB deduped)
# wandb: / 1060.41MB of 1064.24MB uploaded (0.00MB deduped)
# wandb: - 1061.66MB of 1064.24MB uploaded (0.00MB deduped)
# wandb: \ 1062.44MB of 1064.24MB uploaded (0.00MB deduped)
# wandb: | 1063.22MB of 1064.24MB uploaded (0.00MB deduped)
# wandb: / 1063.78MB of 1064.24MB uploaded (0.00MB deduped)
# wandb: - 1064.20MB of 1064.24MB uploaded (0.00MB deduped)
# wandb: \ 1064.20MB of 1064.24MB uploaded (0.00MB deduped)
# wandb: | 1064.20MB of 1064.24MB uploaded (0.00MB deduped)
# wandb: / 1064.20MB of 1064.24MB uploaded (0.00MB deduped)
# wandb: - 1064.20MB of 1064.24MB uploaded (0.00MB deduped)
# wandb: \ 1064.20MB of 1064.24MB uploaded (0.00MB deduped)
# wandb: | 1064.20MB of 1064.24MB uploaded (0.00MB deduped)
# wandb: / 1064.20MB of 1064.24MB uploaded (0.00MB deduped)
# wandb: - 1064.20MB of 1064.24MB uploaded (0.00MB deduped)
# wandb: \ 1064.20MB of 1064.24MB uploaded (0.00MB deduped)
# wandb: | 1064.20MB of 1064.24MB uploaded (0.00MB deduped)
# wandb: / 1064.20MB of 1064.24MB uploaded (0.00MB deduped)
# wandb: - 1064.20MB of 1064.24MB uploaded (0.00MB deduped)
# wandb: \ 1064.20MB of 1064.24MB uploaded (0.00MB deduped)
# wandb: | 1064.20MB of 1064.24MB uploaded (0.00MB deduped)
# wandb: / 1064.20MB of 1064.24MB uploaded (0.00MB deduped)
# wandb: - 1064.20MB of 1064.24MB uploaded (0.00MB deduped)
# wandb: \ 1064.20MB of 1064.24MB uploaded (0.00MB deduped)
# wandb: | 1064.20MB of 1064.24MB uploaded (0.00MB deduped)
# wandb: / 1064.20MB of 1064.24MB uploaded (0.00MB deduped)
# wandb: - 1064.20MB of 1064.24MB uploaded (0.00MB deduped)
# wandb: \ 1064.20MB of 1064.24MB uploaded (0.00MB deduped)
# wandb: | 1064.20MB of 1064.24MB uploaded (0.00MB deduped)
# wandb: / 1064.20MB of 1064.24MB uploaded (0.00MB deduped)
# wandb: - 1064.20MB of 1064.24MB uploaded (0.00MB deduped)
# wandb: \ 1064.20MB of 1064.24MB uploaded (0.00MB deduped)
# wandb: | 1064.20MB of 1064.24MB uploaded (0.00MB deduped)
# wandb: / 1064.20MB of 1064.24MB uploaded (0.00MB deduped)
# wandb: - 1064.20MB of 1064.24MB uploaded (0.00MB deduped)
# wandb: \ 1064.20MB of 1064.24MB uploaded (0.00MB deduped)
# wandb: | 1064.20MB of 1064.24MB uploaded (0.00MB deduped)
# wandb: / 1064.20MB of 1064.24MB uploaded (0.00MB deduped)
# wandb: - 1064.20MB of 1064.24MB uploaded (0.00MB deduped)
# wandb: \ 1064.20MB of 1064.24MB uploaded (0.00MB deduped)
# wandb: | 1064.20MB of 1064.24MB uploaded (0.00MB deduped)
# wandb: / 1064.20MB of 1064.24MB uploaded (0.00MB deduped)
# wandb: - 1064.20MB of 1064.24MB uploaded (0.00MB deduped)
# wandb: \ 1064.20MB of 1064.24MB uploaded (0.00MB deduped)
# wandb: | 1064.20MB of 1064.24MB uploaded (0.00MB deduped)
# wandb: / 1064.20MB of 1064.24MB uploaded (0.00MB deduped)
# wandb: - 1064.20MB of 1064.24MB uploaded (0.00MB deduped)
# wandb: \ 1064.20MB of 1064.24MB uploaded (0.00MB deduped)
# wandb: | 1064.20MB of 1064.24MB uploaded (0.00MB deduped)
# wandb: / 1064.20MB of 1064.24MB uploaded (0.00MB deduped)
# wandb: - 1064.20MB of 1064.24MB uploaded (0.00MB deduped)
# wandb: \ 1064.20MB of 1064.24MB uploaded (0.00MB deduped)
# wandb: | 1064.20MB of 1064.24MB uploaded (0.00MB deduped)
# wandb: / 1064.20MB of 1064.24MB uploaded (0.00MB deduped)
# wandb: - 1064.20MB of 1064.24MB uploaded (0.00MB deduped)
# wandb: \ 1064.20MB of 1064.24MB uploaded (0.00MB deduped)
# wandb: | 1064.20MB of 1064.24MB uploaded (0.00MB deduped)
# wandb: / 1064.20MB of 1064.24MB uploaded (0.00MB deduped)
# wandb: - 1064.20MB of 1064.24MB uploaded (0.00MB deduped)
# wandb: \ 1064.20MB of 1064.24MB uploaded (0.00MB deduped)
# wandb: | 1064.20MB of 1064.24MB uploaded (0.00MB deduped)
# wandb: / 1064.20MB of 1064.24MB uploaded (0.00MB deduped)
# wandb: - 1064.20MB of 1064.24MB uploaded (0.00MB deduped)
# wandb: \ 1064.20MB of 1064.24MB uploaded (0.00MB deduped)
# wandb: | 1064.20MB of 1064.24MB uploaded (0.00MB deduped)
# wandb: / 1064.20MB of 1064.24MB uploaded (0.00MB deduped)
# wandb: - 1064.20MB of 1064.24MB uploaded (0.00MB deduped)
# wandb: \ 1064.20MB of 1064.24MB uploaded (0.00MB deduped)
# wandb: | 1064.20MB of 1064.24MB uploaded (0.00MB deduped)
# wandb: / 1064.20MB of 1064.24MB uploaded (0.00MB deduped)
# wandb: - 1064.20MB of 1064.24MB uploaded (0.00MB deduped)
# wandb: \ 1064.20MB of 1064.24MB uploaded (0.00MB deduped)
# wandb: | 1064.20MB of 1064.24MB uploaded (0.00MB deduped)
# wandb: / 1064.20MB of 1064.24MB uploaded (0.00MB deduped)
# wandb: - 1064.20MB of 1064.24MB uploaded (0.00MB deduped)
# wandb: \ 1064.20MB of 1064.24MB uploaded (0.00MB deduped)
# wandb: | 1064.20MB of 1064.24MB uploaded (0.00MB deduped)
# wandb: / 1064.20MB of 1064.24MB uploaded (0.00MB deduped)
# wandb: - 1064.20MB of 1064.24MB uploaded (0.00MB deduped)
# wandb: \ 1064.20MB of 1064.24MB uploaded (0.00MB deduped)
# wandb: | 1064.20MB of 1064.24MB uploaded (0.00MB deduped)
# wandb: / 1064.20MB of 1064.24MB uploaded (0.00MB deduped)
# wandb: - 1064.20MB of 1064.24MB uploaded (0.00MB deduped)
# wandb: \ 1064.20MB of 1064.24MB uploaded (0.00MB deduped)
# wandb: | 1064.20MB of 1064.24MB uploaded (0.00MB deduped)
# wandb: / 1064.20MB of 1064.24MB uploaded (0.00MB deduped)
# wandb: - 1064.20MB of 1064.24MB uploaded (0.00MB deduped)
# wandb: \ 1064.20MB of 1064.24MB uploaded (0.00MB deduped)
# wandb: | 1064.20MB of 1064.24MB uploaded (0.00MB deduped)
# wandb: / 1064.20MB of 1064.24MB uploaded (0.00MB deduped)
# wandb: - 1064.20MB of 1064.24MB uploaded (0.00MB deduped)
# wandb: \ 1064.20MB of 1064.24MB uploaded (0.00MB deduped)
# wandb: | 1064.20MB of 1064.24MB uploaded (0.00MB deduped)
# wandb: / 1064.20MB of 1064.24MB uploaded (0.00MB deduped)
# wandb: - 1064.20MB of 1064.24MB uploaded (0.00MB deduped)
# wandb: \ 1064.20MB of 1064.24MB uploaded (0.00MB deduped)
# wandb: | 1064.20MB of 1064.24MB uploaded (0.00MB deduped)
# wandb: / 1064.20MB of 1064.24MB uploaded (0.00MB deduped)
# wandb: - 1064.20MB of 1064.24MB uploaded (0.00MB deduped)
# wandb: \ 1064.20MB of 1064.24MB uploaded (0.00MB deduped)
# wandb: | 1064.20MB of 1064.24MB uploaded (0.00MB deduped)
# wandb: / 1064.20MB of 1064.24MB uploaded (0.00MB deduped)
# wandb: - 1064.20MB of 1064.24MB uploaded (0.00MB deduped)
# wandb: \ 1064.20MB of 1064.24MB uploaded (0.00MB deduped)
# wandb: | 1064.20MB of 1064.24MB uploaded (0.00MB deduped)
# wandb: / 1064.20MB of 1064.24MB uploaded (0.00MB deduped)
# wandb: - 1064.20MB of 1064.24MB uploaded (0.00MB deduped)
# wandb: \ 1064.20MB of 1064.24MB uploaded (0.00MB deduped)
# wandb: | 1064.20MB of 1064.24MB uploaded (0.00MB deduped)
# wandb: / 1064.20MB of 1064.24MB uploaded (0.00MB deduped)
# wandb: - 1064.20MB of 1064.24MB uploaded (0.00MB deduped)
# wandb: \ 1064.20MB of 1064.24MB uploaded (0.00MB deduped)
# wandb: | 1064.20MB of 1064.24MB uploaded (0.00MB deduped)
# wandb: / 1064.20MB of 1064.24MB uploaded (0.00MB deduped)
# wandb: - 1064.20MB of 1064.24MB uploaded (0.00MB deduped)
# wandb: \ 1064.20MB of 1064.24MB uploaded (0.00MB deduped)
# wandb: | 1064.20MB of 1064.24MB uploaded (0.00MB deduped)
# wandb: / 1064.20MB of 1064.24MB uploaded (0.00MB deduped)
# wandb: - 1064.20MB of 1064.24MB uploaded (0.00MB deduped)
# wandb: \ 1064.20MB of 1064.24MB uploaded (0.00MB deduped)
# wandb: | 1064.20MB of 1064.24MB uploaded (0.00MB deduped)
# wandb: / 1064.20MB of 1064.24MB uploaded (0.00MB deduped)
# wandb: - 1064.20MB of 1064.24MB uploaded (0.00MB deduped)
# wandb: \ 1064.20MB of 1064.24MB uploaded (0.00MB deduped)
# wandb: | 1064.20MB of 1064.24MB uploaded (0.00MB deduped)
# wandb: / 1064.20MB of 1064.24MB uploaded (0.00MB deduped)
# wandb: - 1064.20MB of 1064.24MB uploaded (0.00MB deduped)
# wandb: \ 1064.20MB of 1064.24MB uploaded (0.00MB deduped)
# wandb: | 1064.20MB of 1064.24MB uploaded (0.00MB deduped)
# wandb: / 1064.20MB of 1064.24MB uploaded (0.00MB deduped)
# wandb: - 1064.20MB of 1064.24MB uploaded (0.00MB deduped)
# wandb: \ 1064.20MB of 1064.24MB uploaded (0.00MB deduped)
# wandb: | 1064.20MB of 1064.24MB uploaded (0.00MB deduped)
# wandb: / 1064.20MB of 1064.24MB uploaded (0.00MB deduped)
# wandb: - 1064.20MB of 1064.24MB uploaded (0.00MB deduped)
# wandb: \ 1064.20MB of 1064.24MB uploaded (0.00MB deduped)
# wandb: | 1064.20MB of 1064.24MB uploaded (0.00MB deduped)
# wandb: / 1064.20MB of 1064.24MB uploaded (0.00MB deduped)
# wandb: - 1064.20MB of 1064.24MB uploaded (0.00MB deduped)
# wandb: \ 1064.20MB of 1064.24MB uploaded (0.00MB deduped)
# wandb: | 1064.20MB of 1064.24MB uploaded (0.00MB deduped)
# wandb: / 1064.20MB of 1064.24MB uploaded (0.00MB deduped)
# wandb: - 1064.20MB of 1064.24MB uploaded (0.00MB deduped)
# wandb: \ 1064.20MB of 1064.24MB uploaded (0.00MB deduped)
# wandb: | 1064.20MB of 1064.24MB uploaded (0.00MB deduped)
# wandb: / 1064.20MB of 1064.24MB uploaded (0.00MB deduped)
# wandb: - 1064.20MB of 1064.24MB uploaded (0.00MB deduped)
# wandb: \ 1064.20MB of 1064.24MB uploaded (0.00MB deduped)
# wandb: | 1064.20MB of 1064.24MB uploaded (0.00MB deduped)
# wandb: / 1064.20MB of 1064.24MB uploaded (0.00MB deduped)
# wandb: - 1064.20MB of 1064.24MB uploaded (0.00MB deduped)
# wandb: \ 1064.20MB of 1064.24MB uploaded (0.00MB deduped)
# wandb: | 1064.20MB of 1064.24MB uploaded (0.00MB deduped)
# wandb: / 1064.20MB of 1064.24MB uploaded (0.00MB deduped)
# wandb: - 1064.20MB of 1064.24MB uploaded (0.00MB deduped)
# wandb: \ 1064.20MB of 1064.24MB uploaded (0.00MB deduped)
# wandb: | 1064.20MB of 1064.24MB uploaded (0.00MB deduped)
# wandb: / 1064.20MB of 1064.24MB uploaded (0.00MB deduped)
# wandb: - 1064.20MB of 1064.24MB uploaded (0.00MB deduped)
# wandb: \ 1064.20MB of 1064.24MB uploaded (0.00MB deduped)
# wandb: | 1064.20MB of 1064.24MB uploaded (0.00MB deduped)
# wandb: / 1064.20MB of 1064.24MB uploaded (0.00MB deduped)
# wandb: - 1064.20MB of 1064.24MB uploaded (0.00MB deduped)
# wandb: \ 1064.20MB of 1064.24MB uploaded (0.00MB deduped)
# wandb: | 1064.20MB of 1064.24MB uploaded (0.00MB deduped)
# wandb: / 1064.20MB of 1064.24MB uploaded (0.00MB deduped)
# wandb: - 1064.20MB of 1064.24MB uploaded (0.00MB deduped)
# wandb: \ 1064.20MB of 1064.24MB uploaded (0.00MB deduped)
# wandb: | 1064.20MB of 1064.24MB uploaded (0.00MB deduped)
# wandb: / 1064.20MB of 1064.24MB uploaded (0.00MB deduped)
# wandb: - 1064.20MB of 1064.24MB uploaded (0.00MB deduped)
# wandb: \ 1064.20MB of 1064.24MB uploaded (0.00MB deduped)
# wandb: | 1064.20MB of 1064.24MB uploaded (0.00MB deduped)
# wandb: / 1064.20MB of 1064.24MB uploaded (0.00MB deduped)
# wandb: - 1064.20MB of 1064.24MB uploaded (0.00MB deduped)
# wandb: \ 1064.20MB of 1064.24MB uploaded (0.00MB deduped)
# wandb: | 1064.20MB of 1064.24MB uploaded (0.00MB deduped)
# wandb: / 1064.20MB of 1064.24MB uploaded (0.00MB deduped)
# wandb: - 1064.20MB of 1064.24MB uploaded (0.00MB deduped)
# wandb: \ 1064.20MB of 1064.24MB uploaded (0.00MB deduped)
# wandb: | 1064.20MB of 1064.24MB uploaded (0.00MB deduped)
# wandb: / 1064.20MB of 1064.24MB uploaded (0.00MB deduped)
# wandb: - 1064.20MB of 1064.24MB uploaded (0.00MB deduped)
# wandb: \ 1064.20MB of 1064.24MB uploaded (0.00MB deduped)
# wandb: | 1064.20MB of 1064.24MB uploaded (0.00MB deduped)
# wandb: / 1064.24MB of 1064.24MB uploaded (0.00MB deduped)
# wandb: - 1064.24MB of 1064.24MB uploaded (0.00MB deduped)
# wandb: \ 1064.24MB of 1064.24MB uploaded (0.00MB deduped)
# wandb: | 1064.24MB of 1064.24MB uploaded (0.00MB deduped)
# wandb: / 1064.24MB of 1064.24MB uploaded (0.00MB deduped)
# wandb: - 1064.24MB of 1064.24MB uploaded (0.00MB deduped)
# wandb:
# wandb: Find user logs for this run at: D:\Datasets\SIIM_RSNA_Covid_Datasets\tmp\yolov5\wandb\run-20210718_172904-3co6ia1q\logs\debug.log
# wandb: Find internal logs for this run at: D:\Datasets\SIIM_RSNA_Covid_Datasets\tmp\yolov5\wandb\run-20210718_172904-3co6ia1q\logs\debug-internal.log
# wandb: Run summary:
# wandb:                 train/box_loss 0.05807
# wandb:                 train/obj_loss 0.01667
# wandb:                 train/cls_loss 0.00027
# wandb:              metrics/precision 0.56928
# wandb:                 metrics/recall 0.42731
# wandb:                metrics/mAP_0.5 0.42982
# wandb:           metrics/mAP_0.5:0.95 0.12686
# wandb:                   val/box_loss 0.05766
# wandb:                   val/obj_loss 0.00856
# wandb:                   val/cls_loss 0.00025
# wandb:                          x/lr0 0.00082
# wandb:                          x/lr1 0.00082
# wandb:                          x/lr2 0.06092
# wandb:                       _runtime 393
# wandb:                     _timestamp 1626644137
# wandb:                          _step 20
# wandb: Synced 5 W&B file(s), 337 media file(s), 20 artifact file(s) and 0 other file(s)
# wandb:
# wandb: Synced exp: https://wandb.ai/ogk01/kaggle-siim-covid/runs/3co6ia1q

# %% [markdown]
# ## Model Saved Automatically as Artifact
#
# Since it's a kernel based competition, you can easily download the best model from the W&B Artifacts UI and upload as a Kaggle dataset that you can load in your inference kernel (internel disabled).
#
# ### [Path to saved model $\rightarrow$](https://wandb.ai/ayush-thakur/kaggle-siim-covid/artifacts/model/run_jbt74n7q_model/4c3ca5752dba99bd227e)
#
# ![img](https://i.imgur.com/KhRLQvR.png)
#
# > 📍 Download the model with the `best` alias tagged to it.

# %% [markdown]
# # Inference
#
# You will probably use a `Submission.ipynb` kernel to run all the predictions. After training a YOLOv5 based object detector -> head to the artifacts page and download the best model -> upload the model as a Kaggle dataset -> Use it with the submission folder.
#
# > 📍 Note that you might have to clone the YOLOv5 repository in a Kaggle dataset as well.
#
# In this section, I will show you how you can do the inference and modify the predicted bounding box coordinates.

# %%
# absolute path
TEST_PATH = 'D:\\Datasets\\SIIM_RSNA_Covid_Datasets\\test_jpeg'

# %% [markdown]
# Since I am training the model in this kernel itself, I will not be using the method that I have described above. The best model is saved in the directory `project_name/exp*/weights/best.pt`. In `exp*`, * can be 1, 2, etc.

# %%
MODEL_PATH = 'kaggle-siim-covid/exp/weights/best.pt'

# %% [markdown]
# ```
# --weights {MODEL_PATH} \ # path to the best model.
# --source {TEST_PATH} \ # absolute path to the test images.
# --img {IMG_SIZE} \ # Size of image
# --conf 0.281 \ # Confidence threshold (default is 0.25)
# --iou-thres 0.5 \ # IOU threshold (default is 0.45)
# --max-det 3 \ # Number of detections per image (default is 1000)
# --save-txt \ # Save predicted bounding box coordinates as txt files
# --save-conf # Save the confidence of prediction for each bounding box
# ```

# %%
# !python detect.py --weights {MODEL_PATH} \
                  --source {TEST_PATH} \
                  --img {IMG_SIZE} \
                  --conf 0.281 \
                  --iou-thres 0.5 \
                  --max-det 3 \
                  --save-txt \
                  --save-conf \
                  --visualize
# Out:
# YOLOv5  v5.0-295-g9dd33fd torch 1.8.1 CUDA:0 (NVIDIA GeForce GTX 1080 Ti, 11264.0MB)
#
# Fusing layers...
# Model Summary: 224 layers, 7056607 parameters, 0 gradients, 16.3 GFLOPs
# D:\Datasets\SIIM_RSNA_Covid_Datasets\tmp\yolov5\utils\plots.py:465: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, ax = plt.subplots(math.ceil(n / 8), 8, tight_layout=True)  # 8 rows x n/8 cols
# Traceback (most recent call last):
#   File "detect.py", line 228, in <module>
#     main(opt)
#   File "detect.py", line 223, in main
#     run(**vars(opt))
#   File "D:\Anaconda\envs\Pytorch\lib\site-packages\torch\autograd\grad_mode.py", line 27, in decorate_context
# detect: weights=['kaggle-siim-covid/exp/weights/best.pt'], source=D:\Datasets\SIIM_RSNA_Covid_Datasets\test_jpeg, imgsz=256, conf_thres=0.281, iou_thres=0.5, max_det=3, device=, view_img=False, save_txt=True, save_conf=True, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=True, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False
# image 1/1263 D:\Datasets\SIIM_RSNA_Covid_Datasets\test_jpeg\0026720152f5.jpg: Saving runs\detect\exp2\0026720152f5\stage0_Focus_features.png... (32/32)
# Saving runs\detect\exp2\0026720152f5\stage1_Conv_features.png... (32/64)
# Saving runs\detect\exp2\0026720152f5\stage2_C3_features.png... (32/64)
# Saving runs\detect\exp2\0026720152f5\stage3_Conv_features.png... (32/128)
# Saving runs\detect\exp2\0026720152f5\stage4_C3_features.png... (32/128)
# Saving runs\detect\exp2\0026720152f5\stage5_Conv_features.png... (32/256)
# Saving runs\detect\exp2\0026720152f5\stage6_C3_features.png... (32/256)
# Saving runs\detect\exp2\0026720152f5\stage7_Conv_features.png... (32/512)
# Saving runs\detect\exp2\0026720152f5\stage8_SPP_features.png... (32/512)
# Saving runs\detect\exp2\0026720152f5\stage9_C3_features.png... (32/512)
# Saving runs\detect\exp2\0026720152f5\stage10_Conv_features.png... (32/256)
# Saving runs\detect\exp2\0026720152f5\stage11_Upsample_features.png... (32/256)
# Saving runs\detect\exp2\0026720152f5\stage12_Concat_features.png... (32/512)
# Saving runs\detect\exp2\0026720152f5\stage13_C3_features.png... (32/256)
# Saving runs\detect\exp2\0026720152f5\stage14_Conv_features.png... (32/128)
# Saving runs\detect\exp2\0026720152f5\stage15_Upsample_features.png... (32/128)
# Saving runs\detect\exp2\0026720152f5\stage16_Concat_features.png... (32/256)
# Saving runs\detect\exp2\0026720152f5\stage17_C3_features.png... (32/128)
# Saving runs\detect\exp2\0026720152f5\stage18_Conv_features.png... (32/128)
# Saving runs\detect\exp2\0026720152f5\stage19_Concat_features.png... (32/256)
# Saving runs\detect\exp2\0026720152f5\stage20_C3_features.png... (32/256)
# Saving runs\detect\exp2\0026720152f5\stage21_Conv_features.png... (32/256)
# Saving runs\detect\exp2\0026720152f5\stage22_Concat_features.png... (32/512)
# Saving runs\detect\exp2\0026720152f5\stage23_C3_features.png... (32/512)
# 256x256 1 opacity, Done. (18.980s)
# image 2/1263 D:\Datasets\SIIM_RSNA_Covid_Datasets\test_jpeg\00fc8fc35dc1.jpg: Saving runs\detect\exp2\00fc8fc35dc1\stage0_Focus_features.png... (32/32)
# Saving runs\detect\exp2\00fc8fc35dc1\stage1_Conv_features.png... (32/64)
# Saving runs\detect\exp2\00fc8fc35dc1\stage2_C3_features.png... (32/64)
# Saving runs\detect\exp2\00fc8fc35dc1\stage3_Conv_features.png... (32/128)
# Saving runs\detect\exp2\00fc8fc35dc1\stage4_C3_features.png... (32/128)
# Saving runs\detect\exp2\00fc8fc35dc1\stage5_Conv_features.png... (32/256)
# Saving runs\detect\exp2\00fc8fc35dc1\stage6_C3_features.png... (32/256)
# Saving runs\detect\exp2\00fc8fc35dc1\stage7_Conv_features.png... (32/512)
# Saving runs\detect\exp2\00fc8fc35dc1\stage8_SPP_features.png... (32/512)
# Saving runs\detect\exp2\00fc8fc35dc1\stage9_C3_features.png... (32/512)
# Saving runs\detect\exp2\00fc8fc35dc1\stage10_Conv_features.png... (32/256)
# Saving runs\detect\exp2\00fc8fc35dc1\stage11_Upsample_features.png... (32/256)
# Saving runs\detect\exp2\00fc8fc35dc1\stage12_Concat_features.png... (32/512)
# Saving runs\detect\exp2\00fc8fc35dc1\stage13_C3_features.png... (32/256)
# Saving runs\detect\exp2\00fc8fc35dc1\stage14_Conv_features.png... (32/128)
# Saving runs\detect\exp2\00fc8fc35dc1\stage15_Upsample_features.png... (32/128)
# Saving runs\detect\exp2\00fc8fc35dc1\stage16_Concat_features.png... (32/256)
# Saving runs\detect\exp2\00fc8fc35dc1\stage17_C3_features.png... (32/128)
# Saving runs\detect\exp2\00fc8fc35dc1\stage18_Conv_features.png... (32/128)
# Saving runs\detect\exp2\00fc8fc35dc1\stage19_Concat_features.png... (32/256)
# Saving runs\detect\exp2\00fc8fc35dc1\stage20_C3_features.png... (32/256)
# Saving runs\detect\exp2\00fc8fc35dc1\stage21_Conv_features.png... (32/256)
# Saving runs\detect\exp2\00fc8fc35dc1\stage22_Concat_features.png... (32/512)
# Saving runs\detect\exp2\00fc8fc35dc1\stage23_C3_features.png... (32/512)
# 256x256 2 opacitys, Done. (19.255s)
# image 3/1263 D:\Datasets\SIIM_RSNA_Covid_Datasets\test_jpeg\01c3512eebc3.jpg: Saving runs\detect\exp2\01c3512eebc3\stage0_Focus_features.png... (32/32)
# Saving runs\detect\exp2\01c3512eebc3\stage1_Conv_features.png... (32/64)
# Saving runs\detect\exp2\01c3512eebc3\stage2_C3_features.png... (32/64)
# Saving runs\detect\exp2\01c3512eebc3\stage3_Conv_features.png... (32/128)
# Saving runs\detect\exp2\01c3512eebc3\stage4_C3_features.png... (32/128)
# Saving runs\detect\exp2\01c3512eebc3\stage5_Conv_features.png... (32/256)
# Saving runs\detect\exp2\01c3512eebc3\stage6_C3_features.png... (32/256)
# Saving runs\detect\exp2\01c3512eebc3\stage7_Conv_features.png... (32/512)
# Saving runs\detect\exp2\01c3512eebc3\stage8_SPP_features.png... (32/512)
# Saving runs\detect\exp2\01c3512eebc3\stage9_C3_features.png... (32/512)
# Saving runs\detect\exp2\01c3512eebc3\stage10_Conv_features.png... (32/256)
# Saving runs\detect\exp2\01c3512eebc3\stage11_Upsample_features.png... (32/256)
# Saving runs\detect\exp2\01c3512eebc3\stage12_Concat_features.png... (32/512)
# Saving runs\detect\exp2\01c3512eebc3\stage13_C3_features.png... (32/256)
# Saving runs\detect\exp2\01c3512eebc3\stage14_Conv_features.png... (32/128)
# Saving runs\detect\exp2\01c3512eebc3\stage15_Upsample_features.png... (32/128)
# Saving runs\detect\exp2\01c3512eebc3\stage16_Concat_features.png... (32/256)
# Saving runs\detect\exp2\01c3512eebc3\stage17_C3_features.png... (32/128)
# Saving runs\detect\exp2\01c3512eebc3\stage18_Conv_features.png... (32/128)
# Saving runs\detect\exp2\01c3512eebc3\stage19_Concat_features.png... (32/256)
# Saving runs\detect\exp2\01c3512eebc3\stage20_C3_features.png... (32/256)
# Saving runs\detect\exp2\01c3512eebc3\stage21_Conv_features.png... (32/256)
# Saving runs\detect\exp2\01c3512eebc3\stage22_Concat_features.png... (32/512)
# Saving runs\detect\exp2\01c3512eebc3\stage23_C3_features.png... (32/512)
# 256x256 Done. (19.675s)
# image 4/1263 D:\Datasets\SIIM_RSNA_Covid_Datasets\test_jpeg\01f948f8e544.jpg: Saving runs\detect\exp2\01f948f8e544\stage0_Focus_features.png... (32/32)
# Saving runs\detect\exp2\01f948f8e544\stage1_Conv_features.png... (32/64)
# Saving runs\detect\exp2\01f948f8e544\stage2_C3_features.png... (32/64)
# Saving runs\detect\exp2\01f948f8e544\stage3_Conv_features.png... (32/128)
# Saving runs\detect\exp2\01f948f8e544\stage4_C3_features.png... (32/128)
# Saving runs\detect\exp2\01f948f8e544\stage5_Conv_features.png... (32/256)
# Saving runs\detect\exp2\01f948f8e544\stage6_C3_features.png... (32/256)
# Saving runs\detect\exp2\01f948f8e544\stage7_Conv_features.png... (32/512)
# Saving runs\detect\exp2\01f948f8e544\stage8_SPP_features.png... (32/512)
# Saving runs\detect\exp2\01f948f8e544\stage9_C3_features.png... (32/512)
# Saving runs\detect\exp2\01f948f8e544\stage10_Conv_features.png... (32/256)
# Saving runs\detect\exp2\01f948f8e544\stage11_Upsample_features.png... (32/256)
# Saving runs\detect\exp2\01f948f8e544\stage12_Concat_features.png... (32/512)
# Saving runs\detect\exp2\01f948f8e544\stage13_C3_features.png... (32/256)
# Saving runs\detect\exp2\01f948f8e544\stage14_Conv_features.png... (32/128)
# Saving runs\detect\exp2\01f948f8e544\stage15_Upsample_features.png... (32/128)
# Saving runs\detect\exp2\01f948f8e544\stage16_Concat_features.png... (32/256)
# Saving runs\detect\exp2\01f948f8e544\stage17_C3_features.png... (32/128)
# Saving runs\detect\exp2\01f948f8e544\stage18_Conv_features.png... (32/128)
# Saving runs\detect\exp2\01f948f8e544\stage19_Concat_features.png... (32/256)
# Saving runs\detect\exp2\01f948f8e544\stage20_C3_features.png... (32/256)
# Saving runs\detect\exp2\01f948f8e544\stage21_Conv_features.png... (32/256)
# Saving runs\detect\exp2\01f948f8e544\stage22_Concat_features.png... (32/512)
# Saving runs\detect\exp2\01f948f8e544\stage23_C3_features.png... (32/512)
# 256x256 Done. (18.729s)
# image 5/1263 D:\Datasets\SIIM_RSNA_Covid_Datasets\test_jpeg\022146012034.jpg: Saving runs\detect\exp2\022146012034\stage0_Focus_features.png... (32/32)
# Saving runs\detect\exp2\022146012034\stage1_Conv_features.png... (32/64)
# Saving runs\detect\exp2\022146012034\stage2_C3_features.png... (32/64)
# Saving runs\detect\exp2\022146012034\stage3_Conv_features.png... (32/128)
# Saving runs\detect\exp2\022146012034\stage4_C3_features.png... (32/128)
# Saving runs\detect\exp2\022146012034\stage5_Conv_features.png... (32/256)
# Saving runs\detect\exp2\022146012034\stage6_C3_features.png... (32/256)
# Saving runs\detect\exp2\022146012034\stage7_Conv_features.png... (32/512)
# Saving runs\detect\exp2\022146012034\stage8_SPP_features.png... (32/512)
# Saving runs\detect\exp2\022146012034\stage9_C3_features.png... (32/512)
# Saving runs\detect\exp2\022146012034\stage10_Conv_features.png... (32/256)
# Saving runs\detect\exp2\022146012034\stage11_Upsample_features.png... (32/256)
# Saving runs\detect\exp2\022146012034\stage12_Concat_features.png... (32/512)
#     return func(*args, **kwargs)
#   File "detect.py", line 104, in run
#     pred = model(img,
#   File "D:\Anaconda\envs\Pytorch\lib\site-packages\torch\nn\modules\module.py", line 889, in _call_impl
#     result = self.forward(*input, **kwargs)
#   File "D:\Datasets\SIIM_RSNA_Covid_Datasets\tmp\yolov5\models\yolo.py", line 123, in forward
#     return self.forward_once(x, profile, visualize)  # single-scale inference, train
#   File "D:\Datasets\SIIM_RSNA_Covid_Datasets\tmp\yolov5\models\yolo.py", line 158, in forward_once
#     feature_visualization(x, m.type, m.i, save_dir=visualize)
#   File "D:\Datasets\SIIM_RSNA_Covid_Datasets\tmp\yolov5\utils\plots.py", line 473, in feature_visualization
#     plt.savefig(save_dir / f, dpi=300, bbox_inches='tight')
#   File "D:\Anaconda\envs\Pytorch\lib\site-packages\matplotlib\pyplot.py", line 859, in savefig
#     res = fig.savefig(*args, **kwargs)
#   File "D:\Anaconda\envs\Pytorch\lib\site-packages\matplotlib\figure.py", line 2311, in savefig
#     self.canvas.print_figure(fname, **kwargs)
#   File "D:\Anaconda\envs\Pytorch\lib\site-packages\matplotlib\backend_bases.py", line 2210, in print_figure
#     result = print_method(
#   File "D:\Anaconda\envs\Pytorch\lib\site-packages\matplotlib\backend_bases.py", line 1639, in wrapper
#     return func(*args, **kwargs)
#   File "D:\Anaconda\envs\Pytorch\lib\site-packages\matplotlib\backends\backend_agg.py", line 509, in print_png
#     FigureCanvasAgg.draw(self)
#   File "D:\Anaconda\envs\Pytorch\lib\site-packages\matplotlib\backends\backend_agg.py", line 402, in draw
#     self.renderer = self.get_renderer(cleared=True)
#   File "D:\Anaconda\envs\Pytorch\lib\site-packages\matplotlib\backends\backend_agg.py", line 418, in get_renderer
#     self.renderer = RendererAgg(w, h, self.figure.dpi)
#   File "D:\Anaconda\envs\Pytorch\lib\site-packages\matplotlib\backends\backend_agg.py", line 96, in __init__
#     self._renderer = _RendererAgg(int(width), int(height), dpi)
# MemoryError: In RendererAgg: Out of memory
# Saving runs\detect\exp2\022146012034\stage13_C3_features.png... (32/256)
# Saving runs\detect\exp2\022146012034\stage14_Conv_features.png... (32/128)
# Saving runs\detect\exp2\022146012034\stage15_Upsample_features.png... (32/128)
# Saving runs\detect\exp2\022146012034\stage16_Concat_features.png... (32/256)
# Saving runs\detect\exp2\022146012034\stage17_C3_features.png... (32/128)
# Saving runs\detect\exp2\022146012034\stage18_Conv_features.png... (32/128)
# Saving runs\detect\exp2\022146012034\stage19_Concat_features.png... (32/256)
# Saving runs\detect\exp2\022146012034\stage20_C3_features.png... (32/256)
# Saving runs\detect\exp2\022146012034\stage21_Conv_features.png... (32/256)
# Saving runs\detect\exp2\022146012034\stage22_Concat_features.png... (32/512)
# Saving runs\detect\exp2\022146012034\stage23_C3_features.png... (32/512)
# 256x256 Done. (19.383s)
# image 6/1263 D:\Datasets\SIIM_RSNA_Covid_Datasets\test_jpeg\02eceb0fc405.jpg: Saving runs\detect\exp2\02eceb0fc405\stage0_Focus_features.png... (32/32)
# Saving runs\detect\exp2\02eceb0fc405\stage1_Conv_features.png... (32/64)
# Saving runs\detect\exp2\02eceb0fc405\stage2_C3_features.png... (32/64)
# Saving runs\detect\exp2\02eceb0fc405\stage3_Conv_features.png... (32/128)
# Saving runs\detect\exp2\02eceb0fc405\stage4_C3_features.png... (32/128)
# Saving runs\detect\exp2\02eceb0fc405\stage5_Conv_features.png... (32/256)
# Saving runs\detect\exp2\02eceb0fc405\stage6_C3_features.png... (32/256)
# Saving runs\detect\exp2\02eceb0fc405\stage7_Conv_features.png... (32/512)
# Saving runs\detect\exp2\02eceb0fc405\stage8_SPP_features.png... (32/512)
# Saving runs\detect\exp2\02eceb0fc405\stage9_C3_features.png... (32/512)
# Saving runs\detect\exp2\02eceb0fc405\stage10_Conv_features.png... (32/256)
# Saving runs\detect\exp2\02eceb0fc405\stage11_Upsample_features.png... (32/256)
# Saving runs\detect\exp2\02eceb0fc405\stage12_Concat_features.png... (32/512)
# Saving runs\detect\exp2\02eceb0fc405\stage13_C3_features.png... (32/256)
# Saving runs\detect\exp2\02eceb0fc405\stage14_Conv_features.png... (32/128)
# Saving runs\detect\exp2\02eceb0fc405\stage15_Upsample_features.png... (32/128)
# Saving runs\detect\exp2\02eceb0fc405\stage16_Concat_features.png... (32/256)
# Saving runs\detect\exp2\02eceb0fc405\stage17_C3_features.png... (32/128)
# Saving runs\detect\exp2\02eceb0fc405\stage18_Conv_features.png... (32/128)
# Saving runs\detect\exp2\02eceb0fc405\stage19_Concat_features.png... (32/256)
# Saving runs\detect\exp2\02eceb0fc405\stage20_C3_features.png... (32/256)
# Saving runs\detect\exp2\02eceb0fc405\stage21_Conv_features.png... (32/256)
# Saving runs\detect\exp2\02eceb0fc405\stage22_Concat_features.png... (32/512)
# Saving runs\detect\exp2\02eceb0fc405\stage23_C3_features.png... (32/512)
# 256x256 Done. (19.787s)
# image 7/1263 D:\Datasets\SIIM_RSNA_Covid_Datasets\test_jpeg\03a778f5a68b.jpg: Saving runs\detect\exp2\03a778f5a68b\stage0_Focus_features.png... (32/32)
# Saving runs\detect\exp2\03a778f5a68b\stage1_Conv_features.png... (32/64)
# Saving runs\detect\exp2\03a778f5a68b\stage2_C3_features.png... (32/64)
# Saving runs\detect\exp2\03a778f5a68b\stage3_Conv_features.png... (32/128)
# Saving runs\detect\exp2\03a778f5a68b\stage4_C3_features.png... (32/128)
# Saving runs\detect\exp2\03a778f5a68b\stage5_Conv_features.png... (32/256)
# Saving runs\detect\exp2\03a778f5a68b\stage6_C3_features.png... (32/256)
# Saving runs\detect\exp2\03a778f5a68b\stage7_Conv_features.png... (32/512)
# Saving runs\detect\exp2\03a778f5a68b\stage8_SPP_features.png... (32/512)
# Saving runs\detect\exp2\03a778f5a68b\stage9_C3_features.png... (32/512)
# Saving runs\detect\exp2\03a778f5a68b\stage10_Conv_features.png... (32/256)
# Saving runs\detect\exp2\03a778f5a68b\stage11_Upsample_features.png... (32/256)
# Saving runs\detect\exp2\03a778f5a68b\stage12_Concat_features.png... (32/512)
# Saving runs\detect\exp2\03a778f5a68b\stage13_C3_features.png... (32/256)
# Saving runs\detect\exp2\03a778f5a68b\stage14_Conv_features.png... (32/128)
# Saving runs\detect\exp2\03a778f5a68b\stage15_Upsample_features.png... (32/128)
# Saving runs\detect\exp2\03a778f5a68b\stage16_Concat_features.png... (32/256)
# Saving runs\detect\exp2\03a778f5a68b\stage17_C3_features.png... (32/128)
# Saving runs\detect\exp2\03a778f5a68b\stage18_Conv_features.png... (32/128)
# Saving runs\detect\exp2\03a778f5a68b\stage19_Concat_features.png... (32/256)
# Saving runs\detect\exp2\03a778f5a68b\stage20_C3_features.png... (32/256)
# Saving runs\detect\exp2\03a778f5a68b\stage21_Conv_features.png... (32/256)
# Saving runs\detect\exp2\03a778f5a68b\stage22_Concat_features.png... (32/512)
# Saving runs\detect\exp2\03a778f5a68b\stage23_C3_features.png... (32/512)
# 256x256 2 opacitys, Done. (16.947s)
# image 8/1263 D:\Datasets\SIIM_RSNA_Covid_Datasets\test_jpeg\03fa9d7e94a8.jpg: Saving runs\detect\exp2\03fa9d7e94a8\stage0_Focus_features.png... (32/32)
# Saving runs\detect\exp2\03fa9d7e94a8\stage1_Conv_features.png... (32/64)
# Saving runs\detect\exp2\03fa9d7e94a8\stage2_C3_features.png... (32/64)
# Saving runs\detect\exp2\03fa9d7e94a8\stage3_Conv_features.png... (32/128)
# Saving runs\detect\exp2\03fa9d7e94a8\stage4_C3_features.png... (32/128)
# Saving runs\detect\exp2\03fa9d7e94a8\stage5_Conv_features.png... (32/256)
# Saving runs\detect\exp2\03fa9d7e94a8\stage6_C3_features.png... (32/256)
# Saving runs\detect\exp2\03fa9d7e94a8\stage7_Conv_features.png... (32/512)
# Saving runs\detect\exp2\03fa9d7e94a8\stage8_SPP_features.png... (32/512)
# Saving runs\detect\exp2\03fa9d7e94a8\stage9_C3_features.png... (32/512)
# Saving runs\detect\exp2\03fa9d7e94a8\stage10_Conv_features.png... (32/256)
# Saving runs\detect\exp2\03fa9d7e94a8\stage11_Upsample_features.png... (32/256)
# Saving runs\detect\exp2\03fa9d7e94a8\stage12_Concat_features.png... (32/512)
# Saving runs\detect\exp2\03fa9d7e94a8\stage13_C3_features.png... (32/256)
# Saving runs\detect\exp2\03fa9d7e94a8\stage14_Conv_features.png... (32/128)
# Saving runs\detect\exp2\03fa9d7e94a8\stage15_Upsample_features.png... (32/128)
# Saving runs\detect\exp2\03fa9d7e94a8\stage16_Concat_features.png... (32/256)
# Saving runs\detect\exp2\03fa9d7e94a8\stage17_C3_features.png... (32/128)
# Saving runs\detect\exp2\03fa9d7e94a8\stage18_Conv_features.png... (32/128)
# Saving runs\detect\exp2\03fa9d7e94a8\stage19_Concat_features.png... (32/256)
# Saving runs\detect\exp2\03fa9d7e94a8\stage20_C3_features.png... (32/256)
# Saving runs\detect\exp2\03fa9d7e94a8\stage21_Conv_features.png... (32/256)
# Saving runs\detect\exp2\03fa9d7e94a8\stage22_Concat_features.png... (32/512)
# Saving runs\detect\exp2\03fa9d7e94a8\stage23_C3_features.png... (32/512)
# 256x256 1 opacity, Done. (20.749s)
# image 9/1263 D:\Datasets\SIIM_RSNA_Covid_Datasets\test_jpeg\040d0765b661.jpg: Saving runs\detect\exp2\040d0765b661\stage0_Focus_features.png... (32/32)
# Saving runs\detect\exp2\040d0765b661\stage1_Conv_features.png... (32/64)
# Saving runs\detect\exp2\040d0765b661\stage2_C3_features.png... (32/64)
# Saving runs\detect\exp2\040d0765b661\stage3_Conv_features.png... (32/128)
# Saving runs\detect\exp2\040d0765b661\stage4_C3_features.png... (32/128)
# Saving runs\detect\exp2\040d0765b661\stage5_Conv_features.png... (32/256)
# Saving runs\detect\exp2\040d0765b661\stage6_C3_features.png... (32/256)
# Saving runs\detect\exp2\040d0765b661\stage7_Conv_features.png... (32/512)
# Saving runs\detect\exp2\040d0765b661\stage8_SPP_features.png... (32/512)
# Saving runs\detect\exp2\040d0765b661\stage9_C3_features.png... (32/512)
# Saving runs\detect\exp2\040d0765b661\stage10_Conv_features.png... (32/256)
# Saving runs\detect\exp2\040d0765b661\stage11_Upsample_features.png... (32/256)
# Saving runs\detect\exp2\040d0765b661\stage12_Concat_features.png... (32/512)
# Saving runs\detect\exp2\040d0765b661\stage13_C3_features.png... (32/256)
# Saving runs\detect\exp2\040d0765b661\stage14_Conv_features.png... (32/128)
# Saving runs\detect\exp2\040d0765b661\stage15_Upsample_features.png... (32/128)
# Saving runs\detect\exp2\040d0765b661\stage16_Concat_features.png... (32/256)
# Saving runs\detect\exp2\040d0765b661\stage17_C3_features.png... (32/128)
# Saving runs\detect\exp2\040d0765b661\stage18_Conv_features.png... (32/128)
# Saving runs\detect\exp2\040d0765b661\stage19_Concat_features.png... (32/256)
# Saving runs\detect\exp2\040d0765b661\stage20_C3_features.png... (32/256)
# Saving runs\detect\exp2\040d0765b661\stage21_Conv_features.png... (32/256)
# Saving runs\detect\exp2\040d0765b661\stage22_Concat_features.png... (32/512)
# Saving runs\detect\exp2\040d0765b661\stage23_C3_features.png... (32/512)
# 256x256 Done. (21.899s)
# image 10/1263 D:\Datasets\SIIM_RSNA_Covid_Datasets\test_jpeg\0418a303883e.jpg: Saving runs\detect\exp2\0418a303883e\stage0_Focus_features.png... (32/32)
# Saving runs\detect\exp2\0418a303883e\stage1_Conv_features.png... (32/64)
# Saving runs\detect\exp2\0418a303883e\stage2_C3_features.png... (32/64)
# Saving runs\detect\exp2\0418a303883e\stage3_Conv_features.png... (32/128)
# Saving runs\detect\exp2\0418a303883e\stage4_C3_features.png... (32/128)
# Saving runs\detect\exp2\0418a303883e\stage5_Conv_features.png... (32/256)
# Saving runs\detect\exp2\0418a303883e\stage6_C3_features.png... (32/256)
# Saving runs\detect\exp2\0418a303883e\stage7_Conv_features.png... (32/512)
# Saving runs\detect\exp2\0418a303883e\stage8_SPP_features.png... (32/512)
# Saving runs\detect\exp2\0418a303883e\stage9_C3_features.png... (32/512)
# Saving runs\detect\exp2\0418a303883e\stage10_Conv_features.png... (32/256)
# Saving runs\detect\exp2\0418a303883e\stage11_Upsample_features.png... (32/256)
# Saving runs\detect\exp2\0418a303883e\stage12_Concat_features.png... (32/512)
# Saving runs\detect\exp2\0418a303883e\stage13_C3_features.png... (32/256)
# Saving runs\detect\exp2\0418a303883e\stage14_Conv_features.png... (32/128)
# Saving runs\detect\exp2\0418a303883e\stage15_Upsample_features.png... (32/128)
# Saving runs\detect\exp2\0418a303883e\stage16_Concat_features.png... (32/256)
# Saving runs\detect\exp2\0418a303883e\stage17_C3_features.png... (32/128)
# Saving runs\detect\exp2\0418a303883e\stage18_Conv_features.png... (32/128)
# Saving runs\detect\exp2\0418a303883e\stage19_Concat_features.png... (32/256)
# Saving runs\detect\exp2\0418a303883e\stage20_C3_features.png... (32/256)
# Saving runs\detect\exp2\0418a303883e\stage21_Conv_features.png... (32/256)
# Saving runs\detect\exp2\0418a303883e\stage22_Concat_features.png... (32/512)
# Saving runs\detect\exp2\0418a303883e\stage23_C3_features.png... (32/512)
# 256x256 Done. (17.033s)
# image 11/1263 D:\Datasets\SIIM_RSNA_Covid_Datasets\test_jpeg\042979d394a1.jpg: Saving runs\detect\exp2\042979d394a1\stage0_Focus_features.png... (32/32)
# Saving runs\detect\exp2\042979d394a1\stage1_Conv_features.png... (32/64)
# Saving runs\detect\exp2\042979d394a1\stage2_C3_features.png... (32/64)
# Saving runs\detect\exp2\042979d394a1\stage3_Conv_features.png... (32/128)
# Saving runs\detect\exp2\042979d394a1\stage4_C3_features.png... (32/128)
# Saving runs\detect\exp2\042979d394a1\stage5_Conv_features.png... (32/256)
# Saving runs\detect\exp2\042979d394a1\stage6_C3_features.png... (32/256)
# Saving runs\detect\exp2\042979d394a1\stage7_Conv_features.png... (32/512)
# Saving runs\detect\exp2\042979d394a1\stage8_SPP_features.png... (32/512)
# Saving runs\detect\exp2\042979d394a1\stage9_C3_features.png... (32/512)
# Saving runs\detect\exp2\042979d394a1\stage10_Conv_features.png... (32/256)
# Saving runs\detect\exp2\042979d394a1\stage11_Upsample_features.png... (32/256)
# Saving runs\detect\exp2\042979d394a1\stage12_Concat_features.png... (32/512)
# Saving runs\detect\exp2\042979d394a1\stage13_C3_features.png... (32/256)
# Saving runs\detect\exp2\042979d394a1\stage14_Conv_features.png... (32/128)
# Saving runs\detect\exp2\042979d394a1\stage15_Upsample_features.png... (32/128)
# Saving runs\detect\exp2\042979d394a1\stage16_Concat_features.png... (32/256)
# Saving runs\detect\exp2\042979d394a1\stage17_C3_features.png... (32/128)
# Saving runs\detect\exp2\042979d394a1\stage18_Conv_features.png... (32/128)
# Saving runs\detect\exp2\042979d394a1\stage19_Concat_features.png... (32/256)
# Saving runs\detect\exp2\042979d394a1\stage20_C3_features.png... (32/256)
# Saving runs\detect\exp2\042979d394a1\stage21_Conv_features.png... (32/256)
# Saving runs\detect\exp2\042979d394a1\stage22_Concat_features.png... (32/512)
# Saving runs\detect\exp2\042979d394a1\stage23_C3_features.png... (32/512)
# 256x256 2 opacitys, Done. (17.016s)
# image 12/1263 D:\Datasets\SIIM_RSNA_Covid_Datasets\test_jpeg
stage1_Conv_features.png... (32/64)
# Saving runs\detect\exp2\349d5e5d8690\stage2_C3_features.png... (32/64)
# Saving runs\detect\exp2\349d5e5d8690\stage3_Conv_features.png... (32/128)
# Saving runs\detect\exp2\349d5e5d8690\stage4_C3_features.png... (32/128)
# Saving runs\detect\exp2\349d5e5d8690\stage5_Conv_features.png... (32/256)
# Saving runs\detect\exp2\349d5e5d8690\stage6_C3_features.png... (32/256)
# Saving runs\detect\exp2\349d5e5d8690\stage7_Conv_features.png... (32/512)
# Saving runs\detect\exp2\349d5e5d8690\stage8_SPP_features.png... (32/512)
# Saving runs\detect\exp2\349d5e5d8690\stage9_C3_features.png... (32/512)
# Saving runs\detect\exp2\349d5e5d8690\stage10_Conv_features.png... (32/256)
# Saving runs\detect\exp2\349d5e5d8690\stage11_Upsample_features.png... (32/256)
# Saving runs\detect\exp2\349d5e5d8690\stage12_Concat_features.png... (32/512)
# Saving runs\detect\exp2\349d5e5d8690\stage13_C3_features.png... (32/256)
# Saving runs\detect\exp2\349d5e5d8690\stage14_Conv_features.png... (32/128)
# Saving runs\detect\exp2\349d5e5d8690\stage15_Upsample_features.png... (32/128)
# Saving runs\detect\exp2\349d5e5d8690\stage16_Concat_features.png... (32/256)
# Saving runs\detect\exp2\349d5e5d8690\stage17_C3_features.png... (32/128)
# Saving runs\detect\exp2\349d5e5d8690\stage18_Conv_features.png... (32/128)
# Saving runs\detect\exp2\349d5e5d8690\stage19_Concat_features.png... (32/256)
# Saving runs\detect\exp2\349d5e5d8690\stage20_C3_features.png... (32/256)
# Saving runs\detect\exp2\349d5e5d8690\stage21_Conv_features.png... (32/256)
# Saving runs\detect\exp2\349d5e5d8690\stage22_Concat_features.png... (32/512)
# Saving runs\detect\exp2\349d5e5d8690\stage23_C3_features.png... (32/512)
# 256x256 Done. (29.000s)
# image 266/1263 D:\Datasets\SIIM_RSNA_Covid_Datasets\test_jpeg\34b713a5bb1d.jpg: Saving runs\detect\exp2\34b713a5bb1d\stage0_Focus_features.png... (32/32)
# Saving runs\detect\exp2\34b713a5bb1d\stage1_Conv_features.png... (32/64)
# Saving runs\detect\exp2\34b713a5bb1d\stage2_C3_features.png... (32/64)
# Saving runs\detect\exp2\34b713a5bb1d\stage3_Conv_features.png... (32/128)
# Saving runs\detect\exp2\34b713a5bb1d\stage4_C3_features.png... (32/128)
# Saving runs\detect\exp2\34b713a5bb1d\stage5_Conv_features.png... (32/256)
# Saving runs\detect\exp2\34b713a5bb1d\stage6_C3_features.png... (32/256)
# Saving runs\detect\exp2\34b713a5bb1d\stage7_Conv_features.png... (32/512)
# Saving runs\detect\exp2\34b713a5bb1d\stage8_SPP_features.png... (32/512)
# Saving runs\detect\exp2\34b713a5bb1d\stage9_C3_features.png... (32/512)
# Saving runs\detect\exp2\34b713a5bb1d\stage10_Conv_features.png... (32/256)
# Saving runs\detect\exp2\34b713a5bb1d\stage11_Upsample_features.png... (32/256)
# Saving runs\detect\exp2\34b713a5bb1d\stage12_Concat_features.png... (32/512)
# Saving runs\detect\exp2\34b713a5bb1d\stage13_C3_features.png... (32/256)
# Saving runs\detect\exp2\34b713a5bb1d\stage14_Conv_features.png... (32/128)
# Saving runs\detect\exp2\34b713a5bb1d\stage15_Upsample_features.png... (32/128)
# Saving runs\detect\exp2\34b713a5bb1d\stage16_Concat_features.png... (32/256)
# Saving runs\detect\exp2\34b713a5bb1d\stage17_C3_features.png... (32/128)
# Saving runs\detect\exp2\34b713a5bb1d\stage18_Conv_features.png... (32/128)
# Saving runs\detect\exp2\34b713a5bb1d\stage19_Concat_features.png... (32/256)
# Saving runs\detect\exp2\34b713a5bb1d\stage20_C3_features.png... (32/256)
# Saving runs\detect\exp2\34b713a5bb1d\stage21_Conv_features.png... (32/256)
# Saving runs\detect\exp2\34b713a5bb1d\stage22_Concat_features.png... (32/512)
# Saving runs\detect\exp2\34b713a5bb1d\stage23_C3_features.png... (32/512)
# 256x256 2 opacitys, Done. (28.381s)
# image 267/1263 D:\Datasets\SIIM_RSNA_Covid_Datasets\test_jpeg\35271bec39b5.jpg: Saving runs\detect\exp2\35271bec39b5\stage0_Focus_features.png... (32/32)
# Saving runs\detect\exp2\35271bec39b5\stage1_Conv_features.png... (32/64)
# Saving runs\detect\exp2\35271bec39b5\stage2_C3_features.png... (32/64)
# Saving runs\detect\exp2\35271bec39b5\stage3_Conv_features.png... (32/128)
# Saving runs\detect\exp2\35271bec39b5\stage4_C3_features.png... (32/128)
# Saving runs\detect\exp2\35271bec39b5\stage5_Conv_features.png... (32/256)
# Saving runs\detect\exp2\35271bec39b5\stage6_C3_features.png... (32/256)
# Saving runs\detect\exp2\35271bec39b5\stage7_Conv_features.png... (32/512)
# Saving runs\detect\exp2\35271bec39b5\stage8_SPP_features.png... (32/512)
# Saving runs\detect\exp2\35271bec39b5\stage9_C3_features.png... (32/512)
# Saving runs\detect\exp2\35271bec39b5\stage10_Conv_features.png... (32/256)
# Saving runs\detect\exp2\35271bec39b5\stage11_Upsample_features.png... (32/256)
# Saving runs\detect\exp2\35271bec39b5\stage12_Concat_features.png... (32/512)
# Saving runs\detect\exp2\35271bec39b5\stage13_C3_features.png... (32/256)
# Saving runs\detect\exp2\35271bec39b5\stage14_Conv_features.png... (32/128)
# Saving runs\detect\exp2\35271bec39b5\stage15_Upsample_features.png... (32/128)
# Saving runs\detect\exp2\35271bec39b5\stage16_Concat_features.png... (32/256)
# Saving runs\detect\exp2\35271bec39b5\stage17_C3_features.png... (32/128)
# Saving runs\detect\exp2\35271bec39b5\stage18_Conv_features.png... (32/128)

# %%
# # Original Code
# !python detect.py --weights {MODEL_PATH} \
#                   --source {TEST_PATH} \
#                   --img {IMG_SIZE} \
#                   --conf 0.281 \
#                   --iou-thres 0.5 \
#                   --max-det 3 \
#                   --save-txt \
#                   --save-conf
# Out:
# usage: detect.py [-h] [--weights WEIGHTS [WEIGHTS ...]] [--source SOURCE]
#                  [--imgsz IMGSZ] [--conf-thres CONF_THRES]
#                  [--iou-thres IOU_THRES] [--max-det MAX_DET] [--device DEVICE]
#                  [--view-img] [--save-txt] [--save-conf] [--save-crop]
#                  [--nosave] [--classes CLASSES [CLASSES ...]] [--agnostic-nms]
#                  [--augment] [--visualize] [--update] [--project PROJECT]
#                  [--name NAME] [--exist-ok] [--line-thickness LINE_THICKNESS]
#                  [--hide-labels] [--hide-conf] [--half]
# detect.py: error: argument --imgsz/--img/--img-size: invalid int value: '{IMG_SIZE}'

# %% [markdown]
# ### How to find the confidence score?
#
# 1. First first the [W&B run page](https://wandb.ai/ayush-thakur/kaggle-siim-covid/runs/jbt74n7q) generated by training the YOLOv5 model.
#
# 2. Go to the media panel -> click on the F1_curve.png file to get a rough estimate of the threshold -> go to the Bounding Box Debugger panel and interactively adjust the confidence threshold.
#
# ![img](https://i.imgur.com/cCUnTBw.gif)

# %% [markdown]
# > 📍 The bounding box coordinates are saved as text file per image name. It is saved in this directory `runs/detect/exp3/labels`.

# %%
PRED_PATH = 'runs/detect/exp3/labels'
# !ls {PRED_PATH}
# Out:
# 00fc8fc35dc1.txt  409322480a9b.txt  858667501a67.txt  bca76008a759.txt
# 03a778f5a68b.txt  413344e1032c.txt  85b6452b47cc.txt  be4b4301c5e4.txt
# 042979d394a1.txt  445298de90b9.txt  86734b7cc20f.txt  be53bfb563b3.txt
# 04396dd5af2f.txt  458417ad6155.txt  87a0829f53c1.txt  beb80bb88a6e.txt
# 04720d7e4e42.txt  4810ae5dbc08.txt  87c51db67bf7.txt  bf30cc575dc9.txt
# 049fce8128f9.txt  4905b651a091.txt  87d8baf120a6.txt  bf5c7ef3b72a.txt
# 04de800ea41a.txt  49c1b06028a1.txt  8829d22c3e2b.txt  bf8e59f80d5c.txt
# 04f4a36c08a2.txt  49e9379c42dc.txt  88782677cbec.txt  c02ef6a70c7e.txt
# 05435da60872.txt  49fb3141efe3.txt  89015a2258aa.txt  c0a746ef9f9f.txt
# 0562436fde50.txt  4b0058c1f54e.txt  8927235865c9.txt  c0f5131b1c99.txt
# 05a70a1c16c1.txt  4c2d931d0f33.txt  898d24f3cda6.txt  c263b1e9aa64.txt
# 05feea9719f5.txt  4d56b2fc668c.txt  89ee5be93326.txt  c28570a073d9.txt
# 06df1e2fde68.txt  4d6c8e93e7c9.txt  8b354d4a216f.txt  c39146cbda47.txt
# 07db3756ec28.txt  4d7b06512cc1.txt  8b6ebd55c8c8.txt  c3c99fea8c77.txt
# 08992bd07010.txt  4e01dd0a5fdf.txt  8b7e42d19053.txt  c3d0378f8856.txt
# 08b12b305a50.txt  4e126f476f86.txt  8b901c5f333a.txt  c3d79bd7e833.txt
# 08bbffaafbe7.txt  4eb36901f082.txt  8bc924bcab6f.txt  c3deaf98bf56.txt
# 0a3a99612b28.txt  4ece84b1cfb8.txt  8c3864112d54.txt  c614d8c2e47e.txt
# 0cc69a8f538c.txt  4eceeddd00ca.txt  8c452e8e1278.txt  c61fe263d5e3.txt
# 0cea7e93db89.txt  4f83ec489a15.txt  8d6d32d0822e.txt  c6a555431645.txt
# 0d47ef3e87e4.txt  4fc12ae446a8.txt  8d6dea06a032.txt  c6c9bf98487a.txt
# 0d50bce86451.txt  4fe0444d7fc5.txt  8ea54e20fd42.txt  c788095df8f2.txt
# 0e97cc4123aa.txt  50201fe80b1b.txt  8f1894f52499.txt  c8538fe73673.txt
# 0f01c0517022.txt  5020cd97beb8.txt  8f925628e0f2.txt  ca107bb3a592.txt
# 262f3525e16a.txt  65be7fc2448a.txt  a82ca8f37fb6.txt  e420d66bb7f8.txt
# 268d472480ec.txt  661343e25b55.txt  a840d15a7cdc.txt  e47df1ad9ccf.txt
# 26f55b8a7a94.txt  6707b082f3c9.txt  a84c79aac3c0.txt  e49489fcf5c0.txt
# 26fa9834387e.txt  670989e56968.txt  a8de2b8aae69.txt  e59126042b0e.txt
# 271bea69026c.txt  6758e5ed7742.txt  a91b4b59c145.txt  e5c56ef2d194.txt
# 27a4a0d2b7ec.txt  67f192ad1a53.txt  a9330037dce2.txt  e5f1d33714e6.txt
# 2857f0e19e09.txt  6828795ea830.txt  a9d318c0b89e.txt  e61e420938b6.txt
# 28d0fa664e61.txt  697a674d44e0.txt  aa6b768d3161.txt  e730aa7fca0a.txt
# 290d07d7480f.txt  699fc1ec26f9.txt  aa6c8c46a05f.txt  e78f51cdf0b8.txt
# 2a316bf62f59.txt  69ffab5539ec.txt  aad5bc70a20e.txt  e7b2a9418b98.txt
# 2b59777ebc31.txt  6a5a6eaef699.txt  ab97e736a971.txt  e831bebfa015.txt
# 2b7e9cf46376.txt  6af96c8a94c9.txt  abd45a0023eb.txt  e8cc6a2f117c.txt
# 2b9cfe857b00.txt  6be63db536d7.txt  abee6a2d0bf5.txt  e9783e91ed84.txt
# 2ba135370ac3.txt  6c0e9f010b2b.txt  acab76326ba1.txt  ea71a8b95d30.txt
# 2bc3736cc7bf.txt  6c45d9b8e386.txt  accc3b15a2d4.txt  ea9ee4d59c59.txt
# 2be1c227dbf2.txt  6ca497c845ef.txt  ad56b89a81c7.txt  eaad41dd9fe3.txt
# 2be224a00fac.txt  6cc1a9065abb.txt  ad97e89134ca.txt  eaec01e48714.txt
# 2c1c4ab77d52.txt  6ce67071aa0e.txt  ad98af65ad2a.txt  eb3fe9eb8e39.txt
# 2d58009c5ade.txt  6d66127d071d.txt  adb60ba82edf.txt  eb632adfa113.txt
# 2d6a4bc38540.txt  6dd0cdbd225f.txt  ae357fad39c2.txt  eb6cabb0b9f2.txt
# 2dad900da56f.txt  6dea3c3d1efa.txt  ae9849096225.txt  ebaebf6b1e02.txt
# 2de24d1c32bb.txt  7035dc2026f0.txt  ae9c9f0b03da.txt  ebf5edbbed2d.txt
# 2fd67e10bfe7.txt  70bee63a6740.txt  aee5e3feb1a2.txt  ecdd379e2a9b.txt
# 303840f71bb5.txt  71dc3bd13f18.txt  af13d77fc159.txt  ed74d42fc445.txt
# 305870c916a4.txt  720a67515500.txt  afc074e1bdb7.txt  ede662a3de87.txt
# 30b1c089724e.txt  7230234e120a.txt  afce260dc959.txt  ee27ca277911.txt
# 317df13caea9.txt  7230f166720e.txt  afd960320c38.txt  ee2b112cdd91.txt
# 318a1ecb6fc7.txt  731b94c566ef.txt  afe360acb63b.txt  eebfaa5e1a65.txt
# 31c07523a69a.txt  7529a3e9745b.txt  b04178e642ed.txt  ef25824e7b3a.txt
# 32b211904f5b.txt  7571cda597cb.txt  b081d24bd60f.txt  ef661638c8c0.txt
